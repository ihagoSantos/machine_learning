# %% [markdown]
# <a href="https://colab.research.google.com/github/ihagoSantos/machine_learning/blob/main/association_rules_shopping_basket_analisys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mlxtend
# !pip install xlrd

# %% [markdown]
# # Analise de Cesta de compras
#
# Fonte: Chris Moffitt (2017), Introduction to Market Basket Analisys in Python, http://pbpython.com/market-basket-analisys.html
#
# Neste exemplo é utilizada a base de dados Online Retail da UCI, disponível em https://archive.ics.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori, association_rules

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a3695122-4a1c-46cc-b2db-eac07ec03b5d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3695122-4a1c-46cc-b2db-eac07ec03b5d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('online-retail.xlsx', sheet_name=0)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  ...  UnitPrice CustomerID         Country
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER  ...       2.55    17850.0  United Kingdom
# 1    536365     71053                  WHITE METAL LANTERN  ...       3.39    17850.0  United Kingdom
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER  ...       2.75    17850.0  United Kingdom
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE  ...       3.39    17850.0  United Kingdom
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.  ...       3.39    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice     CustomerID
# count  541909.000000                         541909  541909.000000  406829.000000
# mean        9.552250  2011-07-04 13:34:57.156386048       4.611114   15287.690570
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000   12346.000000
# 25%         1.000000            2011-03-28 11:34:00       1.250000   13953.000000
# 50%         3.000000            2011-07-19 17:17:00       2.080000   15152.000000
# 75%        10.000000            2011-10-19 11:27:00       4.130000   16791.000000
# max     80995.000000            2011-12-09 12:50:00   38970.000000   18287.000000
# std       218.081158                            NaN      96.759853    1713.600303

# %% [markdown]
# # Preparação de dados
#
# Comando strip() elimina espaços vazios no início e final da string.
#
# Comando dropna() remove registros com valores faltantes (missing values) no campo InvoiceNo.
#
# Comando df[~df['InvoiceNo'].str.contains('C')] remove registros com InvoiceNo iniciados com letra 'C', uma vez que esses campos correspondem a pedidos cancelados.

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str') # Converte InvoiceNo para string
df = df[~df['InvoiceNo'].str.contains('C')]
df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice     CustomerID
# count  532621.000000                         532621  532621.000000  397924.000000
# mean       10.239972  2011-07-04 17:06:10.804305920       3.847621   15294.315171
# min     -9600.000000            2010-12-01 08:26:00  -11062.060000   12346.000000
# 25%         1.000000            2011-03-28 12:13:00       1.250000   13969.000000
# 50%         3.000000            2011-07-20 11:54:00       2.080000   15159.000000
# 75%        10.000000            2011-10-19 12:21:00       4.130000   16795.000000
# max     80995.000000            2011-12-09 12:50:00   13541.330000   18287.000000
# std       159.593551                            NaN      41.758023    1713.169877

# %% [markdown]
# Gera uma base de dados apenas com pedidos da França. É gerada uma tabela pivô em que cada coluna corresponde à um produto e cada linha corresponde ao somatório da quantidade comprada daquele produto em um determinado pedido.

# %%
basket = (
    df[df['Country'] == 'France']
    .groupby(['InvoiceNo', 'Description'])['Quantity']
    .sum().unstack().reset_index().fillna(0)
    .set_index('InvoiceNo')
)
basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                          0.0  ...                              0.0
# 536852                          0.0  ...                              0.0
# 536974                          0.0  ...                              0.0
# 537065                          0.0  ...                              0.0
# 537463                          0.0  ...                              0.0
#
# [5 rows x 1563 columns]

# %% [markdown]
# Transforma as quantidades em 0 e 1.

# %%
def encode_units(x):
  if x <= 0:
    return 0
  if x >= 1:
    return 1

basket_sets = basket.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)

basket_sets.head()
# Out:
# <ipython-input-20-1e9053493a68>:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   basket_sets = basket.applymap(encode_units)
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                            0  ...                                0
# 536852                            0  ...                                0
# 536974                            0  ...                                0
# 537065                            0  ...                                0
# 537463                            0  ...                                0
#
# [5 rows x 1562 columns]

# %%
basket_sets.describe()
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# count                    392.000000  ...                       392.000000
# mean                       0.030612  ...                         0.005102
# std                        0.172485  ...                         0.071337
# min                        0.000000  ...                         0.000000
# 25%                        0.000000  ...                         0.000000
# 50%                        0.000000  ...                         0.000000
# 75%                        0.000000  ...                         0.000000
# max                        1.000000  ...                         1.000000
#
# [8 rows x 1562 columns]

# %% [markdown]
# # Geração de itemsets frequestes e regras de associação

# %%
frequest_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)
frequest_itemsets
# Out:
#      support                                           itemsets
# 0   0.071429                      (4 TRADITIONAL SPINNING TOPS)
# 1   0.096939                       (ALARM CLOCK BAKELIKE GREEN)
# 2   0.102041                        (ALARM CLOCK BAKELIKE PINK)
# 3   0.094388                         (ALARM CLOCK BAKELIKE RED)
# 4   0.081633                     (BAKING SET 9 PIECE RETROSPOT)
# 5   0.071429                     (CHILDRENS CUTLERY DOLLY GIRL)
# 6   0.099490                             (DOLLY GIRL LUNCH BOX)
# 7   0.096939                          (JUMBO BAG RED RETROSPOT)
# 8   0.076531                       (JUMBO BAG WOODLAND ANIMALS)
# 9   0.125000                           (LUNCH BAG APPLE DESIGN)
# 10  0.084184                      (LUNCH BAG DOLLY GIRL DESIGN)
# 11  0.153061                          (LUNCH BAG RED RETROSPOT)
# 12  0.119898                        (LUNCH BAG SPACEBOY DESIGN)
# 13  0.117347                               (LUNCH BAG WOODLAND)
# ...

# %%
rules = association_rules(frequest_itemsets, metric='lift', min_threshold=1)
rules
# Out:
#                                           antecedents  ... zhangs_metric
# 0                        (ALARM CLOCK BAKELIKE GREEN)  ...      0.959283
# 1                         (ALARM CLOCK BAKELIKE PINK)  ...      0.964734
# 2                        (ALARM CLOCK BAKELIKE GREEN)  ...      0.979224
# 3                          (ALARM CLOCK BAKELIKE RED)  ...      0.976465
# 4                          (ALARM CLOCK BAKELIKE RED)  ...      0.960466
# 5                         (ALARM CLOCK BAKELIKE PINK)  ...      0.968652
# 6                              (DOLLY GIRL LUNCH BOX)  ...      0.917139
# 7                                (SPACEBOY LUNCH BOX)  ...      0.943878
# 8                          (PLASTERS IN TIN SPACEBOY)  ...      0.858495
# 9                     (PLASTERS IN TIN CIRCUS PARADE)  ...      0.890096
# 10                    (PLASTERS IN TIN CIRCUS PARADE)  ...      0.863344
# 11                 (PLASTERS IN TIN WOODLAND ANIMALS)  ...      0.866000
# ...

# %% [markdown]
# # Exemplos de filtros sobre regras de associação

# %%
rules[
    (rules['lift'] >= 6) &
    (rules['confidence'] >= 0.8)
]
# Out:
#                                           antecedents  ... zhangs_metric
# 2                        (ALARM CLOCK BAKELIKE GREEN)  ...      0.979224
# 3                          (ALARM CLOCK BAKELIKE RED)  ...      0.976465
# 17                    (SET/6 RED SPOTTY PAPER PLATES)  ...      0.956140
# 18                    (SET/6 RED SPOTTY PAPER PLATES)  ...      0.981725
# 19                      (SET/6 RED SPOTTY PAPER CUPS)  ...      0.993343
# 20  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...  ...      0.956294
# 21  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...  ...      0.967949
# 22  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...  ...      0.953488
#
# [8 rows x 10 columns]

# %%
basket['ALARM CLOCK BAKELIKE RED'].sum()
# Out:
# 316.0

# %%
basket['ALARM CLOCK BAKELIKE GREEN'].sum()
# Out:
# 340.0
