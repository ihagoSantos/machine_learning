# %% [markdown]
# <a href="https://colab.research.google.com/github/ihagoSantos/machine_learning/blob/main/association_rules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regras de Associação

# %%
# !pip install mlxtend
# !pip install xlrd

# %% [markdown]
# # Regras de associação geradas a partir de itemsets frequentes

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.precision', 2)

# %%
# Dataset transacional com cesta de compras
dataset = [
    ['Leite', 'Cebola', 'Batata', 'Feijão', 'Ovos', 'Iogurte'],
    ['Arroz', 'Cebola', 'Batata', 'Feijão', 'Ovos', 'Iogurte'],
    ['Leite', 'Maçã', 'Feijão', 'Ovos'],
    ['Leite', 'Milho', 'Feijão', 'Iogurte'],
    ['Milho', 'Cebola', 'Feijão', 'Sorvete', 'Ovos']
]

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#    Arroz  Batata  Cebola  Feijão  Iogurte  Leite   Maçã  Milho   Ovos  Sorvete
# 0  False    True    True    True     True   True  False  False   True    False
# 1   True    True    True    True     True  False  False  False   True    False
# 2  False   False   False    True    False   True   True  False   True    False
# 3  False   False   False    True     True   True  False   True  False    False
# 4  False   False    True    True    False  False  False   True   True     True

# %%
frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True) # Suporte mínimo = 0.6
frequent_itemsets
# Out:
#     support                itemsets
# 0       0.6                (Cebola)
# 1       1.0                (Feijão)
# 2       0.6               (Iogurte)
# 3       0.6                 (Leite)
# 4       0.8                  (Ovos)
# 5       0.6        (Cebola, Feijão)
# 6       0.6          (Cebola, Ovos)
# 7       0.6       (Iogurte, Feijão)
# 8       0.6         (Leite, Feijão)
# 9       0.8          (Ovos, Feijão)
# 10      0.6  (Cebola, Ovos, Feijão)

# %% [markdown]
# # Regras de associação
# Gera regras de associação com confiança mínima de 0.7

# %%
association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#          antecedents       consequents  antecedent support  \
# 0           (Cebola)          (Feijão)                 0.6
# 1           (Cebola)            (Ovos)                 0.6
# 2             (Ovos)          (Cebola)                 0.8
# 3          (Iogurte)          (Feijão)                 0.6
# 4            (Leite)          (Feijão)                 0.6
# 5             (Ovos)          (Feijão)                 0.8
# 6           (Feijão)            (Ovos)                 1.0
# 7     (Cebola, Ovos)          (Feijão)                 0.6
# 8   (Cebola, Feijão)            (Ovos)                 0.6
# 9     (Ovos, Feijão)          (Cebola)                 0.8
# 10          (Cebola)    (Ovos, Feijão)                 0.6
# 11            (Ovos)  (Cebola, Feijão)                 0.8
#
# ...

# %% [markdown]
# Gera regras de associação com lift mínimo de 1.2.
#
# É importante lembrar que valores lift menor ou igual a 1 significam que a regra não possui causalidade relevante e não aumentam o nosso poder de visão.

# %%
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=1.2)
rules
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#         antecedents       consequents  antecedent support  consequent support  \
# 0          (Cebola)            (Ovos)                 0.6                 0.8
# 1            (Ovos)          (Cebola)                 0.8                 0.6
# 2  (Cebola, Feijão)            (Ovos)                 0.6                 0.8
# 3    (Ovos, Feijão)          (Cebola)                 0.8                 0.6
# 4          (Cebola)    (Ovos, Feijão)                 0.6                 0.8
# 5            (Ovos)  (Cebola, Feijão)                 0.8                 0.6
#
#    support  confidence  lift  leverage  conviction  zhangs_metric
# 0      0.6        1.00  1.25      0.12         inf            0.5
# 1      0.6        0.75  1.25      0.12         1.6            1.0
# ...

# %%
rules['antecedent_len'] = rules['antecedents'].apply(lambda x: len(x))
rules
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#         antecedents       consequents  antecedent support  consequent support  \
# 0          (Cebola)            (Ovos)                 0.6                 0.8
# 1            (Ovos)          (Cebola)                 0.8                 0.6
# 2  (Cebola, Feijão)            (Ovos)                 0.6                 0.8
# 3    (Ovos, Feijão)          (Cebola)                 0.8                 0.6
# 4          (Cebola)    (Ovos, Feijão)                 0.6                 0.8
# 5            (Ovos)  (Cebola, Feijão)                 0.8                 0.6
#
#    support  confidence  lift  leverage  conviction  zhangs_metric  \
# 0      0.6        1.00  1.25      0.12         inf            0.5
# 1      0.6        0.75  1.25      0.12         1.6            1.0
# ...

# %% [markdown]
# Exibe apenas as regras com antecedentes com comprimento maior ou igual a 2 e confiança superior a 0.75 e lift superior a 1.2

# %%
rules[
    (rules['antecedent_len'] >= 2) &
    (rules['confidence'] > 0.75) &
    (rules['lift'] > 1.2)
]
# Out:
#         antecedents consequents  antecedent support  consequent support  \
# 2  (Cebola, Feijão)      (Ovos)                 0.6                 0.8
#
#    support  confidence  lift  leverage  conviction  zhangs_metric  \
# 2      0.6         1.0  1.25      0.12         inf            0.5
#
#    antecedent_len
# 2               2

# %% [markdown]
# Exibe apenas as regras cujo antecedentes são "Feijão" e "Ovos"

# %%
rules[rules['antecedents'] == {"Feijão", "Ovos"}]
# Out:
#       antecedents consequents  antecedent support  consequent support  \
# 3  (Ovos, Feijão)    (Cebola)                 0.8                 0.6
#
#    support  confidence  lift  leverage  conviction  zhangs_metric  \
# 3      0.6        0.75  1.25      0.12         1.6            1.0
#
#    antecedent_len
# 3               2
